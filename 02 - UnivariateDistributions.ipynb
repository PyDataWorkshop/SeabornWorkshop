# %% [markdown]
# `seaborn.distplot()`
# ======================
# * This will flexibly plot a univariate distribution of observations.
#
# * This function combines the matplotlib `hist?()` function
# (with automatic calculation of a good default bin size) with the seaborn
# `kdeplot()` and `rugplot()` functions.
#
# * It can also fit scipy.stats distributions and plot the estimated PDF over
# the data.

# %%
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline 
sns.set(rc={"figure.figsize": (8, 4)});

# %%
# Generate Some Data
np.random.seed(0); x = 2000 + np.floor(100*np.random.randn(100))
x
# Out:
# array([ 2176.,  2040.,  2097.,  2224.,  2186.,  1902.,  2095.,  1984.,
#         1989.,  2041.,  2014.,  2145.,  2076.,  2012.,  2044.,  2033.,
#         2149.,  1979.,  2031.,  1914.,  1744.,  2065.,  2086.,  1925.,
#         2226.,  1854.,  2004.,  1981.,  2153.,  2146.,  2015.,  2037.,
#         1911.,  1801.,  1965.,  2015.,  2123.,  2120.,  1961.,  1969.,
#         1895.,  1857.,  1829.,  2195.,  1949.,  1956.,  1874.,  2077.,
#         1838.,  1978.,  1910.,  2038.,  1948.,  1881.,  1997.,  2042.,
#         2006.,  2030.,  1936.,  1963.,  1932.,  1964.,  1918.,  1827.,
#         2017.,  1959.,  1836.,  2046.,  1909.,  2005.,  2072.,  2012.,
#         2113.,  1876.,  2040.,  1931.,  1912.,  1942.,  1968.,  2005.,
#         1883.,  2090.,  2046.,  1846.,  2148.,  2189.,  2117.,  1982.,
#         1892.,  2105.,  1959.,  2122.,  2020.,  2097.,  2035.,  2070.,
#         2001.,  2178.,  2012.,  2040.])

# %%
ax = sns.distplot(x)
# Out:
# /home/nbuser/anaconda3_410/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
